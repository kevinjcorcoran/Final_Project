# %% [markdown]
# **Playgrounds**
# One other factor that we've taken into account was the number of playgrounds in the different neighboords of the City of Pittsburgh. According to our definition of "Bestness", I thought a neighborhood with the most number of playgrounds that are easily accessible would be the best for raising a family.

# %%
import pandas as pd 
import numpy as np
# %matplotlib inline

# %%
playgrounds_csv = pd.read_csv("https://data.wprdc.org/dataset/playgrounds/resource/47350364-44a8-4d15-b6e0-5f79ddff9367/download/playgrounds.csv")
playgrounds_csv.head(30)
# Out:
#             id                            name  type  \
# 0    731501774            Able Long Playground   NaN
# 1   1461276747        Albert Graham Playground   NaN
# 2   1860709784               Alpine Playground   NaN
# 3   1770671485                Alton Playground   NaN
# 4     18942817                Ammon Playground   NaN
# 5    230731204            Arlington Playground   NaN
# 6    420573029            Armstrong Playground   NaN
# 7    113170092              Arsenal Playground   NaN
# 8   2089697067        August WIlson Playground   NaN
# 9   2124405123           Banksville Playground   NaN
# 10   202656658               Baxter Playground   NaN
# 11   966305264              Bon Air Playground   NaN
# 12  1687972299      Boundary Street Playground   NaN
# 13   966240511     Brighton Heights Playground   NaN
# 14  2126090864            Brookline Playground   NaN
# 15   580160987           Bud Hammer Playground   NaN
# 16  1701961450              Burgwin Playground   NaN
# ...

# %%
playgrounds_csv.groupby('neighborhood')
